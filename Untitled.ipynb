# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
base = pd.read_csv('./data/Use_Of_Force.csv')
base['Occured_date_time'] = pd.to_datetime(base['Occured_date_time'])

# %%
base['Year'] = base['Occured_date_time'].dt.year
base['Month'] = base['Occured_date_time'].dt.month
base['Day'] = base['Occured_date_time'].dt.day

# %% [markdown]
# ### ANALISE DE DADOS POR ANO

# %%
agrupado = base.groupby(['Year'])['Incident_Num'].sum()
agrupado

#Grafico de barras
agrupado.plot.bar(color = 'gray')
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# ### ANALISE DOS MESES DE CADA ANO:

# %%
baseForDate = base.drop(columns=["Incident_Type", "Occured_date_time", "Precinct", "Sector"
                        , "Beat", "Officer_ID", "Subject_ID", "Subject_ID", "Subject_Race", "Subject_Gender"])
baseForDate2014 = baseForDate[baseForDate['Year'] == 2014]
baseForDateG2014 = baseForDate2014.groupby('Month')['Incident_Num'].sum();

baseForDateG2014.plot.bar(color = 'gray')
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
baseForDate2015 = baseForDate[baseForDate['Year'] == 2015]
baseForDateG2015 = baseForDate2015.groupby('Month')['Incident_Num'].sum();

baseForDateG2015.plot.bar(color = 'gray')
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
baseForDate2016 = baseForDate[baseForDate['Year'] == 2016]
baseForDateG2016 = baseForDate2015.groupby('Month')['Incident_Num'].sum();

baseForDateG2016.plot.bar(color = 'gray')
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
baseForDate2017 = baseForDate[baseForDate['Year'] == 2017]
baseForDateG2017 = baseForDate2017.groupby('Month')['Incident_Num'].sum();

baseForDateG2017.plot.bar(color = 'gray')
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
baseForDate2018 = baseForDate[baseForDate['Year'] == 2018]
baseForDateG2018 = baseForDate2018.groupby('Month')['Incident_Num'].sum();

baseForDateG2018.plot.bar(color = 'gray')
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
baseForDate2019 = baseForDate[baseForDate['Year'] == 2019]
baseForDateG2019 = baseForDate2019.groupby('Month')['Incident_Num'].sum();

baseForDateG2019.plot.bar(color = 'gray')
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
baseForDate2020 = baseForDate[baseForDate['Year'] == 2020]
baseForDateG2020 = baseForDate2020.groupby('Month')['Incident_Num'].sum();

baseForDateG2020.plot.bar(color = 'gray')
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
baseForDate2021 = baseForDate[baseForDate['Year'] == 2021]
baseForDateG2021 = baseForDate2021.groupby('Month')['Incident_Num'].sum();

baseForDateG2021.plot.bar(color = 'gray')
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
baseForDate2022 = baseForDate[baseForDate['Year'] == 2022]
baseForDateG2022 = baseForDate2022.groupby('Month')['Incident_Num'].sum();

baseForDateG2022.plot.bar(color = 'gray')
# Out:
# <AxesSubplot:xlabel='Month'>

# %% [markdown]
# ### ANALISE DOS MESES DE CADA SEMANA:

# %%
AAA = baseForDate[baseForDate['Year'] == 2014]
AAA = AAA[AAA['Month'] == 4]
AAA

BBB = AAA.groupby('Day')['Incident_Num'].sum();
BBB
# Out:
# Day
# 1      1329
# 2     13884
# 3     17527
# 4     10764
# 5     20502
# 6     15540
# 8     11576
# 9     12511
# 10    13302
# 11     2781
# 12     2559
# 13     2537
# 14    41389
# 15     5606
# 16     5629
# 18    29485
# 19    46409
# 20     2867
# 21     8722
# 22     2552
# 23     1436
# 24     4298
# 25     4320
# 26    24012
# 27    11147
# 28    15761
# 29    13670
# 30    18804
# Name: Incident_Num, dtype: int64
